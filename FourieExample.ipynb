# %%
# %matplotlib inline

import numpy as np
import matplotlib
import matplotlib.pylab as plt
import plotRoutine as pr

mask = pr.fiber_mask(5, 500, 0.1, 0.25)
M = np.fft2(mask)
plt.figure()
plt.imshow(mask)
plt.colorbar()
